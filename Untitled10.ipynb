# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('../DataSets/CARS.csv')

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.MSRP=df.MSRP.replace('[$,]','',regex=True).astype('int64')
df.Invoice=df.Invoice.replace('[$,]','',regex=True).astype('int64')

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945    33337
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820    21761
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990    24647
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195    30299
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755    39014
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565    38203
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565    40083
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210    42573
# 426  Volvo                      V40  Wagon  Europe      Front  26135    24641
# 427  Volvo                     XC70  Wagon  Europe        All  35145    33112
#
# ...

# %%
df.Type.unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', 'Truck', 'Hybrid'], dtype=object)

# %%
sb.countplot(x=df.Type)
plt.show()

# %%
sb.stripplot(x=df.Type,y=df.MSRP)
plt.show()

# %%
sb.stripplot(x=df.Type,y=df.MSRP,palette='hot')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_11336\1097075714.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.stripplot(x=df.Type,y=df.MSRP,palette='hot')

# %%
s=df.groupby('Type')['MSRP'].sum()

# %%
s
# Out:
# Type
# Hybrid      59760
# SUV       2087415
# Sedan     7800688
# Sports    2615966
# Truck      598593
# Wagon      865216
# Name: MSRP, dtype: int64

# %%
plt.pie(s.values,labels=s.index,autopct='%d%%')
plt.show()

# %%
plt.pie(s.values,labels=s.index,autopct='%d%%')
plt.show()

# %%
sb.barplot(x=df.Type,y=df.MSRP,palette='summer')
plt.show()

# %%
sb.lineplot(x=df.Type,y=df.MSRP)
plt.show()

# %%
sb.lmplot(df,x='MSRP',y='Invoice')
plt.show()
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.distplot(df.MSRP)
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_11336\4119491299.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.MSRP)

# %%
sb.swarmplot(df.Invoice)
plt.show()

# %%
sb.swarmplot(df.Invoice,palette='hot')
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_11336\3512756487.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(df.Invoice,palette='hot')

# %%
sb.jointplot(x=df.Invoice,y=df.MSRP)
plt.show()

# %%
sb.jointplot(x=df.Invoice,y=df.Cylinders)
plt.show()

# %%
df.MSRP.plot.area()
plt.show()

# %%
df.Invoice.plot.area()
plt.show()

# %%
df.EngineSize.plot.area()
plt.show()

# %%
sb.jointplot(x=df.Invoice,y=df.MSRP,palette='hot')
plt.show()
