# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../DataSets/CARS.csv")

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df.Make.unique
# Out:
# <bound method Series.unique of 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Acura
#        ...
# 423    Volvo
# 424    Volvo
# 425    Volvo
# 426    Volvo
# 427    Volvo
# Name: Make, Length: 428, dtype: object>

# %%
df.Make.value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %%
df.Invoice = df.Invoice.replace('[$,]','',regex=True).astype("float")
df.MSRP = df.MSRP.replace("[$,]","",regex=True).astype('int64')
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945  33337.0
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820  21761.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990  24647.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195  30299.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755  39014.0
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565  38203.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565  40083.0
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210  42573.0
# 426  Volvo                      V40  Wagon  Europe      Front  26135  24641.0
# 427  Volvo                     XC70  Wagon  Europe        All  35145  33112.0
#
# ...

# %%
df.groupby('Make')['Invoice'].mean()
# Out:
# Make
# Acura            38590.857143
# Audi             39330.105263
# BMW              39620.650000
# Buick            27854.888889
# Cadillac         46426.875000
# Chevrolet        24060.814815
# Chrysler         25270.066667
# Dodge            24160.076923
# Ford             21953.000000
# GMC              26289.375000
# Honda            19512.764706
# Hummer           45815.000000
# Hyundai          16035.333333
# Infiniti         32880.000000
# Isuzu            24619.000000
# Jaguar           56098.416667
# Jeep             22644.666667
# Kia              14890.363636
# Land Rover       41851.000000
# Lexus            38760.000000
# Lincoln          39135.777778
# MINI             16787.000000
# Mazda            20192.454545
# Mercedes-Benz    56453.307692
# Mercury          25657.555556
# Mitsubishi       21834.769231
# Nissan           22997.470588
# Oldsmobile       21749.000000
# Pontiac          22159.636364
# Porsche          73662.857143
# Saab             35620.285714
# ...

# %%
df.Type.unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', 'Truck', 'Hybrid'], dtype=object)

# %%
L=[1,2,3,4,5,6]

# %%
L[1]
# Out:
# 2

# %%
L[0]
# Out:
# 1

# %%
L[0]
# Out:
# 1

# %%
df.Type.unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', 'Truck', 'Hybrid'], dtype=object)

# %%
pd.crosstab(index=df.Make,columns=df.Invoice,margins=True)
# Out:
# Invoice        9875.0  10107.0  10144.0  10319.0  10642.0  10705.0  10896.0  \
# Make
# Acura               0        0        0        0        0        0        0
# Audi                0        0        0        0        0        0        0
# BMW                 0        0        0        0        0        0        0
# Buick               0        0        0        0        0        0        0
# Cadillac            0        0        0        0        0        0        0
# Chevrolet           0        0        0        0        0        0        0
# Chrysler            0        0        0        0        0        0        0
# Dodge               0        0        0        0        0        0        0
# Ford                0        0        0        0        0        0        0
# GMC                 0        0        0        0        0        0        0
# Honda               0        0        0        0        0        0        0
# ...

# %%
a=np.random.randint(1,200,size=45)

# %%
a
# Out:
# array([111,  24, 131, 161, 158,  21, 110, 155,  52,  59, 110,   8,  36,
#         35,   8, 198,  30,  13,   5, 196,  94, 134, 107,  26,  12,  24,
#         45, 128,  82, 191, 180,  56,  50, 185,  45,   6,  32,  59, 198,
#         80,  80,  63,  96,  68, 169])

# %%
a.reshape(9,5)
# Out:
# array([[111,  24, 131, 161, 158],
#        [ 21, 110, 155,  52,  59],
#        [110,   8,  36,  35,   8],
#        [198,  30,  13,   5, 196],
#        [ 94, 134, 107,  26,  12],
#        [ 24,  45, 128,  82, 191],
#        [180,  56,  50, 185,  45],
#        [  6,  32,  59, 198,  80],
#        [ 80,  63,  96,  68, 169]])

# %%
a=np.random.randint(1,99,size=20)

# %%
a
# Out:
# array([81, 63,  7, 12, 25, 83, 61, 58, 45,  8,  6, 81, 41, 81, 78, 27, 55,
#        85, 61, 70])

# %%
np.resize(5,5)
# Out:
# array([5, 5, 5, 5, 5])

# %%
a
# Out:
# array([81, 63,  7, 12, 25, 83, 61, 58, 45,  8,  6, 81, 41, 81, 78, 27, 55,
#        85, 61, 70])

# %%
 def car(x):
    if x>=10280 and x<=25000:
        return 'low_b'
    elif x>=25000 and x<=50000:
        return 'mid_b'
    elif x>=50000 and x<=80000:
        return 'high_b'
    else:
        return 'super_car'

# %%
df['price']=df.MSRP.apply(car)

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945  33337.0
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820  21761.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990  24647.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195  30299.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755  39014.0
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565  38203.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565  40083.0
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210  42573.0
# 426  Volvo                      V40  Wagon  Europe      Front  26135  24641.0
# 427  Volvo                     XC70  Wagon  Europe        All  35145  33112.0
#
# ...

# %%
df[df.Make == 'Audi']
# Out:
#     Make                             Model    Type  Origin DriveTrain   MSRP  \
# 7   Audi                       A4 1.8T 4dr   Sedan  Europe      Front  25940
# 8   Audi            A41.8T convertible 2dr   Sedan  Europe      Front  35940
# 9   Audi                        A4 3.0 4dr   Sedan  Europe      Front  31840
# 10  Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All  33430
# 11  Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All  34480
# 12  Audi                        A6 3.0 4dr   Sedan  Europe      Front  36640
# 13  Audi                A6 3.0 Quattro 4dr   Sedan  Europe        All  39640
# 14  Audi            A4 3.0 convertible 2dr   Sedan  Europe      Front  42490
# 15  Audi    A4 3.0 Quattro convertible 2dr   Sedan  Europe        All  44240
# 16  Audi          A6 2.7 Turbo Quattro 4dr   Sedan  Europe        All  42840
# 17  Audi                A6 4.2 Quattro 4dr   Sedan  Europe        All  49690
# ...

# %%
df[(df.Make == 'Audi')&(df.Type == 'Sports')]
# Out:
#     Make                             Model    Type  Origin DriveTrain   MSRP  \
# 20  Audi                          RS 6 4dr  Sports  Europe      Front  84600
# 21  Audi    TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front  35940
# 22  Audi  TT 1.8 Quattro 2dr (convertible)  Sports  Europe        All  37390
# 23  Audi    TT 3.2 coupe 2dr (convertible)  Sports  Europe        All  40590
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 20  76417.0         4.2        8.0         450        15           22    4024
# 21  32512.0         1.8        4.0         180        20           28    3131
# 22  33891.0         1.8        4.0         225        20           28    2921
# 23  36739.0         3.2        6.0         250        21           29    3351
#
#     Wheelbase  Length      price
# 20        109     191  super_car
# 21         95     159      mid_b
# 22         96     159      mid_b
# 23         96     159      mid_b

# %%
a=df[(df.MSRP<=32700)&(df.Horsepower>=215)]

# %%
a
# Out:
#               Make                               Model    Type  Origin  \
# 9             Audi                          A4 3.0 4dr   Sedan  Europe
# 51           Buick                        Regal GS 4dr   Sedan     USA
# 57        Cadillac                         CTS VVT 4dr   Sedan     USA
# 65       Chevrolet                      TrailBlazer LT     SUV     USA
# 77       Chevrolet                       Impala SS 4dr   Sedan     USA
# 94        Chrysler                            300M 4dr   Sedan     USA
# 96        Chrysler                    Concorde LXi 4dr   Sedan     USA
# 97        Chrysler                   PT Cruiser GT 4dr   Sedan     USA
# 104       Chrysler                            Pacifica   Wagon     USA
# 105          Dodge                         Durango SLT     SUV     USA
# 111          Dodge                     Intrepid ES 4dr   Sedan     USA
# 113          Dodge                   Grand Caravan SXT   Sedan     USA
# ...

# %%
print(df.Make.unique())
a=input('Enter car name')
d=df[df.Make==a]
d.groupby('MSRP')['Horsepower'].sum()
d.groupby('Type')[['Horsepower','Model']].sum()
# Out:
# ['Acura' 'Audi' 'BMW' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler' 'Dodge'
#  'Ford' 'GMC' 'Honda' 'Hummer' 'Hyundai' 'Infiniti' 'Isuzu' 'Jaguar'
#  'Jeep' 'Kia' 'Land Rover' 'Lexus' 'Lincoln' 'MINI' 'Mazda'
#  'Mercedes-Benz' 'Mercury' 'Mitsubishi' 'Nissan' 'Oldsmobile' 'Pontiac'
#  'Porsche' 'Saab' 'Saturn' 'Scion' 'Subaru' 'Suzuki' 'Toyota' 'Volkswagen'
#  'Volvo']
# Enter car nameBuick
#        Horsepower                                              Model
# Type
# SUV           460                               RainierRendezvous CX
# Sedan        1470  Century Custom 4drLeSabre Custom 4drRegal LS 4...

# %%
print(df.Make.unique())
car=input('Enter car brand name')
sujju=df[df.Make==car]
print(sujju.Type.unique())
typ=input('enter type name')
c=sujju[sujju.Type==typ]
sb.barplot(x=c.Model,y=c.MSRP)
plt.scatter(df.MPG_City,df.MPG_Highway)
plt.xticks(rotation=90)
plt.show()
# Out:
# ['Acura' 'Audi' 'BMW' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler' 'Dodge'
#  'Ford' 'GMC' 'Honda' 'Hummer' 'Hyundai' 'Infiniti' 'Isuzu' 'Jaguar'
#  'Jeep' 'Kia' 'Land Rover' 'Lexus' 'Lincoln' 'MINI' 'Mazda'
#  'Mercedes-Benz' 'Mercury' 'Mitsubishi' 'Nissan' 'Oldsmobile' 'Pontiac'
#  'Porsche' 'Saab' 'Saturn' 'Scion' 'Subaru' 'Suzuki' 'Toyota' 'Volkswagen'
#  'Volvo']
# Enter car brand nameBMW
# ['SUV' 'Sedan' 'Sports' 'Wagon']
# enter type nameSports

# %%
print(df.Make.unique())
car=input('Enter car brand name')
sujju=df[df.Make==car]
print(sujju.Type.unique())
typ=input('enter type name')
c=sujju[sujju.Type==typ]
print(df.Origin.unique())
city=input('enter cities name')
cit=c[c.Origin==city]
sb.barplot(x=c.Model,y=c.MSRP)
plt.xticks(rotation=90)
plt.show()
# Out:
# ['Acura' 'Audi' 'BMW' 'Buick' 'Cadillac' 'Chevrolet' 'Chrysler' 'Dodge'
#  'Ford' 'GMC' 'Honda' 'Hummer' 'Hyundai' 'Infiniti' 'Isuzu' 'Jaguar'
#  'Jeep' 'Kia' 'Land Rover' 'Lexus' 'Lincoln' 'MINI' 'Mazda'
#  'Mercedes-Benz' 'Mercury' 'Mitsubishi' 'Nissan' 'Oldsmobile' 'Pontiac'
#  'Porsche' 'Saab' 'Saturn' 'Scion' 'Subaru' 'Suzuki' 'Toyota' 'Volkswagen'
#  'Volvo']
# Enter car brand nameMercedes-Benz
# ['SUV' 'Sedan' 'Sports' 'Wagon']
# enter type nameWagon
# ['Asia' 'Europe' 'USA']
# enter cities nameUSA

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        All  36945  33337.0
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  23820  21761.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  26990  24647.0
# 3    Acura                   TL 4dr  Sedan    Asia      Front  33195  30299.0
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  43755  39014.0
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  40565  38203.0
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  42565  40083.0
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  45210  42573.0
# 426  Volvo                      V40  Wagon  Europe      Front  26135  24641.0
# 427  Volvo                     XC70  Wagon  Europe        All  35145  33112.0
#
# ...

# %%
df[(df.Make == 'Audi')&(df.Type == 'Sports')&(df.MSRP >=32000)]
# Out:
#     Make                             Model    Type  Origin DriveTrain   MSRP  \
# 20  Audi                          RS 6 4dr  Sports  Europe      Front  84600
# 21  Audi    TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front  35940
# 22  Audi  TT 1.8 Quattro 2dr (convertible)  Sports  Europe        All  37390
# 23  Audi    TT 3.2 coupe 2dr (convertible)  Sports  Europe        All  40590
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 20  76417.0         4.2        8.0         450        15           22    4024
# 21  32512.0         1.8        4.0         180        20           28    3131
# 22  33891.0         1.8        4.0         225        20           28    2921
# 23  36739.0         3.2        6.0         250        21           29    3351
#
#     Wheelbase  Length      price
# 20        109     191  super_car
# 21         95     159      mid_b
# 22         96     159      mid_b
# 23         96     159      mid_b

# %%
df[(df.Make == 'Audi')&(df.Type == 'Sports')&(df.MSRP >=35940)]
# Out:
#     Make                             Model    Type  Origin DriveTrain   MSRP  \
# 20  Audi                          RS 6 4dr  Sports  Europe      Front  84600
# 21  Audi    TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front  35940
# 22  Audi  TT 1.8 Quattro 2dr (convertible)  Sports  Europe        All  37390
# 23  Audi    TT 3.2 coupe 2dr (convertible)  Sports  Europe        All  40590
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 20  76417.0         4.2        8.0         450        15           22    4024
# 21  32512.0         1.8        4.0         180        20           28    3131
# 22  33891.0         1.8        4.0         225        20           28    2921
# 23  36739.0         3.2        6.0         250        21           29    3351
#
#     Wheelbase  Length      price
# 20        109     191  super_car
# 21         95     159      mid_b
# 22         96     159      mid_b
# 23         96     159      mid_b

# %%
df[(df.Make == 'Audi')&(df.Type == 'Sports')&(df.MSRP <= 35940)]
# Out:
#     Make                           Model    Type  Origin DriveTrain   MSRP  \
# 21  Audi  TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front  35940
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 21  32512.0         1.8        4.0         180        20           28    3131
#
#     Wheelbase  Length  price
# 21         95     159  mid_b

# %%
df[(df.Make == 'Audi')&(df.Type == 'Sports')&(df.MSRP ==35940)]
# Out:
#     Make                           Model    Type  Origin DriveTrain   MSRP  \
# 21  Audi  TT 1.8 convertible 2dr (coupe)  Sports  Europe      Front  35940
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 21  32512.0         1.8        4.0         180        20           28    3131
#
#     Wheelbase  Length  price
# 21         95     159  mid_b

# %%
plt.scatter(df.MPG_City,df.MPG_Highway)
plt.show()

# %%
num=[]
while True:
    user = input('Enter a number or S to complete')
    if user == 'S':
       break
    try:
        no=int(user)
        num.append(no)
    except ValueError:
        print('Invalid statement')
    total=sum(num)
    print('The sum of the number is:',total)

# %%
sb.histplot(df.Horsepower,bins=40)
plt.show()

# %%
for i in['Horsepower','Cylinders','MPG_Highway','Length']:
    sb.histplot(df[i])
    plt.title('column name are %s'%i)
    plt.show()

# %%
sb.kdeplot(df.Wheelbase)
plt.show()

# %%
sb.distplot(df.Horsepower)
plt.show()

# %%
sb.distplot(df.Wheelbase,bins=20)
plt.show()

# %%
sb.distplot(df.Horsepower,bins=20)
plt.show()

# %%
plt.scatter(df.MPG_City,df.MSRP)
plt.show()

# %%
sb.countplot(x=df.Type,palette='summer')
plt.show()

# %%
sb.stripplot(x=df.Type,y=df.Horsepower)
plt.show()

# %%
sb.stripplot(x=df.Type,y=df.Horsepower,palette='winter')

# %%
sb.stripplot(x=df.Type,y=df.Horsepower,palette='gist_yarg_r')
plt.show()

# %%
su=df.groupby('Make')['Length'].sum()

# %%
sb.lineplot(x=df.Model,y=df.Length)
plt.show()
